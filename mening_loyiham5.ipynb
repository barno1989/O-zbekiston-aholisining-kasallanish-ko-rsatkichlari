# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
# Out:
#              years  acute_intestinal_infections  bacterial_dysentery  \
# 0             2000                         44.6                  4.9
# 1             2001                         42.4                  4.8
# 2             2002                         40.0                  4.8
# 3             2003                         34.2                  3.9
# 4             2004                         33.2                  3.5
# 5             2005                         36.6                  3.8
# 6             2006                         35.5                  3.4
# 7             2007                         32.5                  3.1
# 8             2008                         33.4                  2.9
# 9             2009                         32.7                  2.6
# 10            2010                         33.8                  2.9
# 11            2011                         31.8                  2.7
# 12            2012                         33.2                  2.3
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
plt.bar(X, Y, color='b')
plt.xticks(rotation = 90)
plt.title("O'zbekiston aholisining o'tkir ichak infeksiyalari bilan kasallanishi darajasi")
plt.xlabel("Yillar")
plt.ylabel("O'tkir ichak infeksiyalari, mingta holat")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 2])
  
plt.plot(X, Y, color='g')
plt.xticks(rotation = 90)
plt.title("O'zbekiston aholisining bakterial dizenteriya bilan kasallanishi darajasi")
plt.xlabel("Yillar")
plt.ylabel("Bakterial dizenteriya, mingta holat")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 3])
  
plt.step(X, Y, color='r')
plt.xticks(rotation = 90)
plt.title("O'zbekiston aholisining salmonellez bilan kasallanishi darajasi")
plt.xlabel("Yillar")
plt.ylabel("Salmonellez, mingta holat")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
fig, axs = plt.subplots(2,2,figsize=(18,10))
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
x = list(df.iloc[:, 0])
y = list(df.iloc[:, 4])
z = list(df.iloc[:, 5])
w = list(df.iloc[:, 6])
k = list(df.iloc[:, 7])
fig.suptitle('Ozbekiston aholisining yuqumli kasalliklar bilan kasallanish korsatkichlari')
plt.xticks(rotation = 90)
axs[0,0].plot(x, y,'tab:red')
axs[0, 0].set_title('Ichterlama va paratiflar, mingta holat')
axs[0,1].plot(x, z, 'tab:purple')
axs[0, 1].set_title('Gripp va ORVI, mingta holat')
axs[1,0].plot(x, w, 'tab:brown')
axs[1, 0].set_title('Virusli gepatit, mingta holat')
axs[1,1].plot(x, k)
axs[1,1].set_title('Skarlatina, mingta holat')
# Out:
# Text(0.5, 1.0, 'Skarlatina, mingta holat')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
fig, axs = plt.subplots(2,2,figsize=(18,10))
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
x = list(df.iloc[:, 0])
y = list(df.iloc[:, 8])
z = list(df.iloc[:, 9])
w = list(df.iloc[:, 10])
k = list(df.iloc[:, 11])
fig.suptitle('Ozbekiston aholisining yuqumli kasalliklar bilan kasallanish korsatkichlari')
plt.xticks(rotation = 90)
axs[0,0].plot(x, y,'tab:orange')
axs[0, 0].set_title('Kokyotal, mingta holat')
axs[0,1].plot(x, z, 'tab:green')
axs[0, 1].set_title('Qizamiq, mingta holat')
axs[1,0].plot(x, w, 'tab:red')
axs[1, 0].set_title('Meningokokkli infeksiya, mingta holat')
axs[1,1].plot(x, k)
axs[1,1].set_title('Brutsellyoz, mingta holat')
# Out:
# Text(0.5, 1.0, 'Brutsellyoz, mingta holat')

# %%
sskorsatkich = pd.read_csv ('SS_korsatkichlari.csv')
sskorsatkich
# Out:
#               years  hospital_beds  beds_pregnant  capacity_clinics  \
# 0              2000           55.9           40.5             157.7
# 1              2001           55.8           39.6             160.4
# 2              2002           57.8           37.6             163.1
# 3              2003           57.4           35.7             159.2
# 4              2004           54.9           32.0             155.2
# 5              2005           54.1           31.0             152.7
# 6              2006           53.9           29.1             153.2
# 7              2007           51.3           26.9             153.1
# 8              2008           49.9           25.9             150.2
# 9              2009           49.8           25.3             148.4
# 10             2010           47.9           24.0             145.1
# 11             2011           47.3           23.4             143.4
# 12             2012           46.1           22.7             141.5
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
sskorsatkich = pd.read_csv ('SS_korsatkichlari.csv')

df = pd.DataFrame(sskorsatkich)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
plt.scatter(X, Y, color='y')
plt.xticks(rotation = 90)
plt.title("Sogliqni saqlash korsatkichlari")
plt.xlabel("Yillar")
plt.ylabel("10 000 aholiga shifoxona orinlari soni")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
sskorsatkich = pd.read_csv ('SS_korsatkichlari.csv')

df = pd.DataFrame(sskorsatkich)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 4])
  
plt.barh(X, Y, color='c')

plt.title("Sogliqni saqlash korsatkichlari")
plt.xlabel("Yillar")
plt.ylabel("10 000 aholiga shifokorlar soni")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
fig, axs = plt.subplots(2,2,figsize=(18,10))
sskorsatkich=pd.read_csv ('SS_korsatkichlari.csv')

df = pd.DataFrame(sskorsatkich)
x = list(df.iloc[:, 0])
y = list(df.iloc[:, 2])
z = list(df.iloc[:, 3])
w = list(df.iloc[:, 4])
k = list(df.iloc[:, 5])
fig.suptitle('Sogliqni saqlash korsatkichlari')
plt.xticks(rotation = 90)
axs[0,0].plot(x, y,'tab:grey')
axs[0, 0].set_title('10 000 homilador ayolga orinlar soni')
axs[0,1].plot(x, z, 'tab:orange')
axs[0, 1].set_title('10 000 aholiga ambulatoriya-poliklinika muassasalari quvvati')
axs[1,0].plot(x, w)
axs[1, 0].set_title('10 000 aholiga shifokorlar soni')
axs[1,1].plot(x, k, 'purple')
axs[1,1].set_title('10 000 aholiga orta tibbiyot hodimlari soni')
# Out:
# Text(0.5, 1.0, '10 000 aholiga orta tibbiyot hodimlari soni')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

df = pd.read_csv('SS_korsatkichlari.csv')
fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3, sharey=True);
fig.suptitle('Sogliqni saqlash korsatkichlari', fontsize=21)
ax[0].hist(df['hospital_beds'])
ax[0].set_title('10 000 aholiga shifoxona orinlari soni', fontsize=14)
ax[0].set_xlabel('Orinlar soni', fontsize=15)
ax[0].set_ylabel('Yillar', fontsize=15)
ax[1].hist(df['beds_pregnant'])
ax[1].set_title('10 000 homilador ayolga orinlar soni', fontsize=14)
ax[1].set_xlabel('Orinlar soni', fontsize=15)
ax[1].set_ylabel('Yillar', fontsize=15)
ax[2].hist(df['capacity_clinics'])
ax[2].set_title('10 000 aholiga ambulatoriya-poliklinika muassasalari quvvati', fontsize=14)
ax[2].set_xlabel('Bir smenada qatnovlar soni', fontsize=15)
ax[2].set_ylabel('Yillar', fontsize=15)
plt.subplots_adjust(top=0.85, wspace=0.15)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

df = pd.read_csv('SS_korsatkichlari.csv')
fig, ax = plt.subplots(figsize=(18,6), nrows=1, ncols=3, sharey=True);
fig.suptitle('Sogliqni saqlash korsatkichlari', fontsize=21)
index = np.arange(5)values1 = ['hospital_beds','beds_pregnant','capacity_clinics']plt.bar(index, values1)plt.xticks(index+0.4,['A','B','C','D','E'])
ax[0].bar(df['hospital_beds'])
ax[0].set_title('10 000 aholiga shifoxona orinlari soni', fontsize=14)
ax[0].set_xlabel('Orinlar soni', fontsize=15)
ax[0].set_ylabel('Yillar', fontsize=15)
ax[1].bar(df['beds_pregnant'])
ax[1].set_title('10 000 homilador ayolga orinlar soni', fontsize=14)
ax[1].set_xlabel('Orinlar soni', fontsize=15)
ax[1].set_ylabel('Yillar', fontsize=15)
ax[2].bar(df['capacity_clinics'])
ax[2].set_title('10 000 aholiga ambulatoriya-poliklinika muassasalari quvvati', fontsize=14)
ax[2].set_xlabel('Bir smenada qatnovlar soni', fontsize=15)
ax[2].set_ylabel('Yillar', fontsize=15)
plt.subplots_adjust(top=0.85, wspace=0.15)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
emlash = pd.read_csv ('bolalarni-emlash.csv')
emlash
# Out:
#        Yillar_Years Diphteria Pertussis Poliomielitis Tetanus Measles
# 0              1991         -         -             -       -       -
# 1              1992      83.3      78.4          85.3       -       -
# 2              1993      49.2      44.7          45.9       -       -
# 3              1994      66.7      65.2            79       -       -
# 4              1995      85.1      84.1          98.2       -       -
# 5              1996      95.7        95          96.6       -       -
# 6              1997      96.6      95.8          97.9       -       -
# 7              1998      98.4        98            99       -       -
# 8              1999      98.8      98.3            99       -       -
# 9              2000      99.1      99.1          99.1    99.1    99.1
# 10             2001      99.1      98.9          99.4    99.1    98.9
# 11             2002      98.8      98.5          99.4    98.7    96.8
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
emlash = pd.read_csv ('bolalarni-emlash.csv')
emlash
df = pd.DataFrame(emlash)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
plt.bar(X, Y, color='m')
plt.xticks(rotation = 90)
plt.title("O'zbekistonda bir yoshgacha bolgan bolalarni emlash korsatkichi")
plt.xlabel("Yillar")
plt.ylabel("Difteriyaga qarshi emlash, foiz")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
fig, axs = plt.subplots(2,2,figsize=(18,12))
emlash = pd.read_csv ('bolalarni-emlash.csv')

df = pd.DataFrame(emlash)
x = list(df.iloc[:, 0])
y = list(df.iloc[:, 2])
z = list(df.iloc[:, 3])
w = list(df.iloc[:, 4])
k = list(df.iloc[:, 5])
fig.suptitle('Ozbekistonda bir yoshgacha bolgan bolalarni emlash korsatkichi')
plt.xticks(rotation = 90)
axs[0,0].plot(x, y,'P')
axs[0, 0].set_title('Kokyotalga qarshi emlash, foiz')
axs[0,1].plot(x, z, '+')
axs[0, 1].set_title('Poliomielitga qarshi emlash, foiz')
axs[1,0].plot(x, w, 'x')
axs[1, 0].set_title('Qoqsholga qarshi emlash, foiz')
axs[1,1].plot(x, k, 'X')
axs[1,1].set_title('Qizamiqqa qarshi emlash, foiz')
# Out:
# Text(0.5, 1.0, 'Qizamiqqa qarshi emlash, foiz')
